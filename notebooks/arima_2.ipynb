# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import pmdarima as pm

# %%
from pmdarima.datasets.stocks import load_msft

df = load_msft()
df.head()
# Out:
#          Date     Open     High      Low    Close      Volume  OpenInt
# 0  1986-03-13  0.06720  0.07533  0.06720  0.07533  1371330506        0
# 1  1986-03-14  0.07533  0.07533  0.07533  0.07533   409569463        0
# 2  1986-03-17  0.07533  0.07533  0.07533  0.07533   176995245        0
# 3  1986-03-18  0.07533  0.07533  0.07533  0.07533    90067008        0
# 4  1986-03-19  0.07533  0.07533  0.07533  0.07533    63655515        0

# %%
from pandas.plotting import lag_plot

fig, axes = plt.subplots(3, 2, figsize=(8, 12))
plt.title('MSFT Autocorrelation plot')
# plt.figure(figsize=(20,7), dpi=180)

# The axis coordinates for the plots
ax_idcs = [
    (0, 0),
    (0, 1),
    (1, 0),
    (1, 1),
    (2, 0),
    (2, 1)
]

for lag, ax_coords in enumerate(ax_idcs, 1):
    ax_row, ax_col = ax_coords
    axis = axes[ax_row][ax_col]
    lag_plot(df['Open'], lag=lag, ax=axis)
    axis.set_title(f"Lag={lag}")
# plt.figure(figsize=(20,7), dpi=180)
plt.show()

# %%
from pmdarima.arima import ndiffs

kpss_diffs = ndiffs(y_train, alpha=0.05, test='kpss', max_d=6)
adf_diffs = ndiffs(y_train, alpha=0.05, test='adf', max_d=6)
n_diffs = max(adf_diffs, kpss_diffs)

print(f"Estimated differencing term: {n_diffs}")
# Estimated differencing term: 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/darioarias/Desktop_2/DM_Stock/notebooks/arima_2.ipynb Cell 4' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/Users/darioarias/Desktop_2/DM_Stock/notebooks/arima_2.ipynb#ch0000019?line=0'>1</a> from pmdarima.arima import ndiffs
# ----> <a href='vscode-notebook-cell:/Users/darioarias/Desktop_2/DM_Stock/notebooks/arima_2.ipynb#ch0000019?line=2'>3</a> kpss_diffs = ndiffs(y_train, alpha=0.05, test='kpss', max_d=6)
#       <a href='vscode-notebook-cell:/Users/darioarias/Desktop_2/DM_Stock/notebooks/arima_2.ipynb#ch0000019?line=3'>4</a> adf_diffs = ndiffs(y_train, alpha=0.05, test='adf', max_d=6)
#       <a href='vscode-notebook-cell:/Users/darioarias/Desktop_2/DM_Stock/notebooks/arima_2.ipynb#ch0000019?line=4'>5</a> n_diffs = max(adf_diffs, kpss_diffs)
#
# NameError: name 'y_train' is not defined
